# %%
path = r"C:\Users\Jelil\Downloads\archive (1).zip"

# %%
import zipfile
import pandas as pd

path = r"C:\Users\Jelil\Downloads\archive (1).zip"

with zipfile.ZipFile(path, "r") as z:
    print(z.namelist())

    df1 = pd.read_csv(z.open("MLTempDataset.csv"))
    df2 = pd.read_csv(z.open("MLTempDataset1.csv"))
# Out:
# ['MLTempDataset.csv', 'MLTempDataset1.csv']

# %%
df2.head(3)
# Out:
#    Unnamed: 0             Datetime  Hourly_Temp
# 0           0  2022-01-04 00:00:00       20.867
# 1           1  2022-01-04 01:00:00       21.000
# 2           2  2022-01-04 02:00:00       20.867

# %%
df1.head(3)
# Out:
#    Unnamed: 0  Datetime1  DAYTON_MW             Datetime
# 0           0          0     20.867  2022-01-04 00:00:00
# 1           1          1     21.000  2022-01-04 01:00:00
# 2           2          2     20.867  2022-01-04 02:00:00

# %%
df2.index = df2["Datetime"]
df2.index = pd.to_datetime(df2.index)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7056 entries, 2022-01-04 00:00:00 to 2022-10-24 23:00:00
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   7056 non-null   int64
#  1   Datetime     7056 non-null   object
#  2   Hourly_Temp  7056 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 220.5+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7056 entries, 2022-01-04 00:00:00 to 2022-10-24 23:00:00
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Hourly_Temp  7056 non-null   float64
#  1   Diff         7055 non-null   float64
# dtypes: float64(2)
# memory usage: 165.4 KB

# %%
df2["Hourly_Temp"].rolling(24*7).mean().plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
df2.drop(columns = ["Unnamed: 0", "Datetime"], inplace = True)

# %%
df2.drop(columns = ["Diff"], inplace = True)

# %%
df2.head()
# Out:
#                      Hourly_Temp
# Datetime
# 2022-01-04 00:00:00       20.867
# 2022-01-04 01:00:00       21.000
# 2022-01-04 02:00:00       20.867
# 2022-01-04 03:00:00       20.650
# 2022-01-04 04:00:00       20.400

# %% [markdown]
# Creating a rolling window

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.figure(figsize=(12,5))
plot_acf(df2["Diff"])
plt.show()

plt.figure(figsize=(12,5))
plot_pacf(df2["Diff"], method='ywm')
plt.show()

# %%
import numpy as np
np.array(df2.iloc[1:7,].values.flatten())
# Out:
# array([21.   , 20.867, 20.65 , 20.4  , 20.1  , 19.8  ])

# %%
split = int(len(df2)*0.8)
split
# Out:
# 5644

# %%
X = df2.iloc[:split]
y = df2.iloc[split:]

# %%
print(X.shape, y.shape)
# Out:
# (5644, 1) (1412, 1)

# %%
def rolling_window(data, window = 7):
    X = []
    y = []
    for i in range(len(data)-window):
        X.append(data.iloc[i : i + window-1].values.flatten())
        y.append(data.iloc[i + window].values.flatten())

    return np.array(X), np.array(y)

# %%
X_train, y_train = rolling_window(X, 14)
X_test, y_test = rolling_window(y, 14)

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from xgboost import XGBRegressor
from sklearn.preprocessing import RobustScaler


pipeline = make_pipeline(
    RobustScaler(),
    XGBRegressor(
        objective="reg:squarederror",
        random_state=42
    )
)


params = {
    "xgbregressor__n_estimators": [200, 300, 400],
    "xgbregressor__max_depth": [4, 6, 8],
    "xgbregressor__learning_rate": [0.01, 0.05, 0.1],
    "xgbregressor__subsample": [0.7, 0.9],
}

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=params,
    cv=5,
    n_jobs=-1,
    verbose=1
)

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                        ('xgbregressor',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      callbacks=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_bynode=None,
#                                                      colsample_bytree=None,
#                                                      device=None,
#                                                      early_stopping_rounds=None,
#                                                      enable_categorical=False,
#                                                      eval_metric=None,
# ...

# %%
grid.best_params_
# Out:
# {'xgbregressor__learning_rate': 0.01,
#  'xgbregressor__max_depth': 4,
#  'xgbregressor__n_estimators': 400,
#  'xgbregressor__subsample': 0.7}

# %%
X[2]
# Out:
# array([20.867, 20.65 , 20.4  , 20.1  , 19.8  , 19.5  , 19.4  , 19.5  ,
#        19.933, 20.75 , 21.833, 22.75 , 23.7  ])

# %%
y.shape
# Out:
# (7042, 1)

# %%
df1.dropna(inplace = True)

# %%
df1.head(5)
# Out:
#                                Datetime1
# 1970-01-01 00:00:00.000000000          0
# 1970-01-01 00:00:00.000000001          1
# 1970-01-01 00:00:00.000000002          2
# 1970-01-01 00:00:00.000000003          3
# 1970-01-01 00:00:00.000000004          4

# %%
y_pred = grid.predict(X_test)

# %%
print(len(y_pred), type(y_pred))
# Out:
# 1398 <class 'numpy.ndarray'>

# %%
print(len(y_test), type(y_test))
# Out:
# 1398 <class 'numpy.ndarray'>

# %%
df_result = pd.DataFrame(y_test)

# %%
df_result["predicted"] = y_pred
df_result.iloc[500:530]

# %%
df_result.iloc[500:530]
# Out:
#           0  predicted
# 500  21.800  21.978214
# 501  21.822  21.813881
# 502  22.060  21.937557
# 503  22.400  21.944332
# 504  22.900  22.047041
# 505  23.100  22.239294
# 506  22.683  22.641863
# 507  22.460  22.918020
# 508  22.100  22.319601
# 509  21.717  22.178623
# 510  22.000  21.918789
# 511  21.817  21.936592
# 512  21.533  22.026381
# 513  21.533  21.980938
# 514  21.980  21.988798
# 515  22.400  21.982170
# 516  22.750  22.080774
# 517  22.940  22.281696
# 518  23.100  22.524235
# 519  23.200  22.641863
# 520  23.129  22.847347
# 521  22.871  22.807173
# 522  22.600  22.746668
# 523  22.483  22.494043
# 524  22.600  22.131483
# 525  22.940  22.160809
# 526  23.550  22.231951
# 527  24.043  22.605196
# 528  24.550  23.562733
# 529  24.940  23.811953

# %%
min_temp, max_temp = min(df_result["predicted"].iloc[500:530]), max(df_result["predicted"].iloc[500:530])

# %%
round(min_temp-1, 1), round(max_temp+1,1)
# Out:
# (20.8, 24.8)

# %%
min_temp, max_temp = min(y_test[500:530]), max(y_test[500:530])

# %%
min_temp, max_temp
# Out:
# (array([21.533]), array([24.94]))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# %%
print(f" mean absolute error is: {mae} and meansquared error is {mse}")
# Out:
#  mean absolute error is: 1.539036924375826 and meansquared error is 6.776621948412163

# %%
grid.predict
# Out:
# <bound method BaseSearchCV.predict of GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                        ('xgbregressor',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      callbacks=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_bynode=None,
#                                                      colsample_bytree=None,
#                                                      device=None,
#                                                      early_stopping_rounds=None,
#                                                      enable_categorical=False,
#                                                      eval_metric=None,
# ...

# %% [markdown]
# ⭐ Quick rule of thumb
#
# Your MAE is good if:
# MAE<10% of the average target value
#
# Your MSE is good if:
# sqrtroot(MSE)≈MAE
#
# Since:
# sqrtroot(6.776)≈2.60
#
# This means your errors are not dominated by huge outliers — that’s a healthy sign.

# %%
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", mape)
# Out:
# MAPE: 23.573219623617323

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV

clf = make_pipeline(
    RobustScaler(),
    XGBRegressor(
        objective="reg:squarederror",
        random_state=42
    )
)


params = {
    "xgbregressor__n_estimators": [200, 300, 400],
    "xgbregressor__max_depth": [4, 6, 8],
    "xgbregressor__learning_rate": [0.01, 0.05, 0.1],
    "xgbregressor__subsample": [0.7, 0.9],
}


model = RandomizedSearchCV(
    estimator=clf,
    param_distributions=params,
    n_iter = 20,
    cv=5,
    n_jobs=-1,
    verbose=1
)


model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                              ('xgbregressor',
#                                               XGBRegressor(base_score=None,
#                                                            booster=None,
#                                                            callbacks=None,
#                                                            colsample_bylevel=None,
#                                                            colsample_bynode=None,
#                                                            colsample_bytree=None,
#                                                            device=None,
#                                                            early_stopping_rounds=None,
#                                                            enable_categorical=False,
# ...

# %%
y_pred = model.predict(X_test)

# %%
df_result["predicted"] = y_pred
df_result.iloc[500:530]
# Out:
#           0  predicted
# 500  21.800  21.978214
# 501  21.822  21.813881
# 502  22.060  21.937557
# 503  22.400  21.944332
# 504  22.900  22.047041
# 505  23.100  22.239294
# 506  22.683  22.641863
# 507  22.460  22.918020
# 508  22.100  22.319601
# 509  21.717  22.178623
# 510  22.000  21.918789
# 511  21.817  21.936592
# 512  21.533  22.026381
# 513  21.533  21.980938
# 514  21.980  21.988798
# 515  22.400  21.982170
# 516  22.750  22.080774
# 517  22.940  22.281696
# 518  23.100  22.524235
# 519  23.200  22.641863
# 520  23.129  22.847347
# 521  22.871  22.807173
# 522  22.600  22.746668
# 523  22.483  22.494043
# 524  22.600  22.131483
# 525  22.940  22.160809
# 526  23.550  22.231951
# 527  24.043  22.605196
# 528  24.550  23.562733
# 529  24.940  23.811953

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# %%
print(f" mean absolute error is: {mae} and meansquared error is {mse}")
# Out:
#  mean absolute error is: 1.539036924375826 and meansquared error is 6.776621948412163
